# %% [markdown]
# <a href="https://colab.research.google.com/github/Limonsitox/StephaniF-SSF-oto24-Stehani-Vianey-Francisco-Limon/blob/main/A3_%C2%BFque_significa%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Simplemente lo revisé, construyeron un howitzer de neutrones para convertir torio en uranio mediante captura de neutrones. Un howitzer de neutrones consiste en una fuente fuerte de alfa (hay algunos grandes artículos de la década de 1960 que hablan sobre pedir plutonio para eso como si pidieras una pizza, junto con comentarios como "dejamos fuera el blindaje de cadmio para ahorrar costos"), hoy en día usarías Am241 para sacar neutrones del berilio, por lo que originalmente era una fuente de Pu-Be y ahora es una fuente de Am-Be. Así que ahora tienes una fuente de neutrones térmicos (lentos) que puedes usar para transmutar A a B (su mención de "hojas de carbono de termalización" se refiere al uso de carbono como moderador para ralentizarlos a velocidades térmicas; los neutrones rápidos no son útiles porque atraviesan las cosas sin interactuar con ellas).
#
# La magia fue el equipo especializado que usaron para detectar los resultados; normalmente usarías un espectrómetro de rayos gamma, pero ellos recurrieron a la detección de los subproductos del proceso de creación porque había muy poco material presente.
